# %% [markdown]
# Center for World University Rankings (CWUR)
# - https://cwur.org/about.php

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm.autonotebook import tqdm
from postdocsalary.paths import DATA_DIR, ensure_dir
import urllib.request

# %%
university_rankings = pd.read_csv(DATA_DIR / 'university_rankings' / 'cwur2022-USA.csv')

# %%
number_columns = ['Quality of Education Rank','Alumni Employment Rank','Quality of Faculty Rank','Research Performance Rank', 'World Rank']

# %%
for nc in number_columns:
    if university_rankings[nc].dtype == object:
        university_rankings[nc] = np.array([int(i) if i.isnumeric() else np.nan  for i in university_rankings[nc].values])

# %%
university_rankings[nc].dtype
# Out:
# dtype('int64')

# %%
len(university_rankings)
# Out:
# 347

# %%
university_rankings[:50]
# Out:
#     World Rank                                      Institution Country  \
# 0            1                               Harvard University     USA
# 1            2            Massachusetts Institute of Technology     USA
# 2            3                              Stanford University     USA
# 3            6                             Princeton University     USA
# 4            7                              Columbia University     USA
# 5            8                            University of Chicago     USA
# 6            9                       University of Pennsylvania     USA
# 7           10                                  Yale University     USA
# 8           11               California Institute of Technology     USA
# 9           12               University of California, Berkeley     USA
# 10          14                               Cornell University     USA
# 11          15                University of Michigan, Ann Arbor     USA
# ...

# %%
university_rankings.sort_values(by='Research Performance Rank')[:20]
# Out:
#     World Rank                              Institution Country  \
# 0            1                       Harvard University     USA
# 2            3                      Stanford University     USA
# 11          15        University of Michigan, Ann Arbor     USA
# 12          16                 Johns Hopkins University     USA
# 1            2    Massachusetts Institute of Technology     USA
# 17          23       University of Washington - Seattle     USA
# 6            9               University of Pennsylvania     USA
# 9           12       University of California, Berkeley     USA
# 14          18    University of California, Los Angeles     USA
# 4            7                      Columbia University     USA
# 21          34      University of California, San Diego     USA
# 7           10                          Yale University     USA
# 5            8                    University of Chicago     USA
# 15          20                          Duke University     USA
# ...

# %%
university_rankings.sort_values(by='Alumni Employment Rank')[:20]
# Out:
#      World Rank                            Institution Country  National Rank  \
# 0             1                     Harvard University     USA              1
# 2             3                    Stanford University     USA              3
# 6             9             University of Pennsylvania     USA              7
# 1             2  Massachusetts Institute of Technology     USA              2
# 4             7                    Columbia University     USA              5
# 3             6                   Princeton University     USA              4
# 5             8                  University of Chicago     USA              6
# 24           40                      Dartmouth College     USA             25
# 13           17                Northwestern University     USA             14
# 10           14                     Cornell University     USA             11
# 104         314          Southern Methodist University     USA            105
# ...

# %%
university_rankings.sort_values(by='Quality of Faculty Rank')[:20]
# Out:
#     World Rank                                 Institution Country  \
# 0            1                          Harvard University     USA
# 1            2       Massachusetts Institute of Technology     USA
# 2            3                         Stanford University     USA
# 9           12          University of California, Berkeley     USA
# 27          49                      Rockefeller University     USA
# 3            6                        Princeton University     USA
# 8           11          California Institute of Technology     USA
# 4            7                         Columbia University     USA
# 16          22  University of Illinois at Urbana–Champaign     USA
# 21          34         University of California, San Diego     USA
# 7           10                             Yale University     USA
# 20          33               University of Texas at Austin     USA
# 14          18       University of California, Los Angeles     USA
# ...
